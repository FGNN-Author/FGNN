# %%
# %load_ext autoreload
# %autoreload 2

import layers
import model
import data

from model import *
from data import *

# %%
model = unet_sym(None, (128,128,1), 32)
model.summary()
# Out:
# lft 8
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# lift_1 (Lift)                   (None, 128, 128, 8)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_sym_24 (Conv2DSym)       (None, 128, 128, 16) 146         lift_1[0][0]
# __________________________________________________________________________________________________
# conv2d_sym_25 (Conv2DSym)       (None, 128, 128, 16) 290         conv2d_sym_24[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# fg = RotFlipSymGen
# #fg = RotationSymGen


# inputs = Input((128,128,1))
# inputLf = Lift(fg)(inputs)
# conv1 = Conv2DSym(32, 3, fg, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputLf)
# pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)    
# conv2 = Conv2DSym(32, 3, fg, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
# out = Drop(fg)(conv2)

# model = Model(inputs=inputs, outputs=out)

# model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])
# model.summary()

# %%
def flip(X): return tf.reverse(X, axis=[-2])
def rot(X): return tf.image.rot90(X)

# %%
# 1 liner...
a = np.random.rand(1, 128, 128,1)

def diff(a, b):
    # Print maximum abs difference.
    print(np.amax(np.abs(a-b)), flush=True)
    
diff(model.predict(a), rot(model.predict(a)))
diff(rot(model.predict(a)), model.predict(rot(a)))

diff(flip(model.predict(a)), model.predict(flip(a)))
# Out:
# 0.3046806
# 9.536743e-07
# 9.536743e-07
